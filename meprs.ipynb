# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# # Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# # Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

# import kagglehub
# # kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

user_secrets = UserSecretsClient()
token = user_secrets.get_secret("HF_TOKEN")

login(token)

# %%
# %cd ..
# !rm -rf DeAR-Reranking

# !git clone -b medprs-eval https://github.com/tnt1626/DeAR-Reranking.git
# %cd DeAR-Reranking
# Out:
# /kaggle
# Cloning into 'DeAR-Reranking'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 116 (delta 53), reused 105 (delta 42), pack-reused 0 (from 0)
# Receiving objects: 100% (116/116), 176.54 KiB | 2.23 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# /kaggle/DeAR-Reranking

# %%
# 1. Tạo thư mục chứa dữ liệu MedPRS
# !mkdir -p data_MedPRS

# 2. Copy 2 file CSV từ dataset đã upload vào thư mục vừa tạo
# !cp /kaggle/input/datasets/tintngc/medprs-dataset/journal_category.csv data_MedPRS/
# !cp /kaggle/input/datasets/tintngc/medprs-dataset/val_set.csv data_MedPRS/

# 3. Copy file checkpoint (Sử dụng ký tự * để tự động khớp tên file dài/bị rút gọn)
# !cp /kaggle/input/datasets/tintngc/medprs-dataset/Epoch_02_SIMCPRS_dmis-lab_biobert-v1_1_CL.pth Epoch_02_SIMCPRS_dmis-lab_biobert-v1_1_CL.pth

# !cp /kaggle/input/datasets/tintngc/medprs-dataset/journal_embeddings.npy data_MedPRS/ 2>/dev/null || true

# %%
# !pip install rankify[all] pytrec-eval bitsandbytes peft transformers accelerate pandas numpy tqdm
# !pip install -q peft bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 46.0 MB/s eta 0:00:00

# %%
# !python run_medprs_inference_qwen.py --500
# Out:
# === MEDPRS JOURNAL RECOMMENDATION INFERENCE PIPELINE (QWEN CO-T) ===
# Using device: cuda
# Loading datasets...
# Loaded 1406 journals and 120346 validation papers.
# Loading BioBERT tokenizer and base model...
# config.json: 100%|█████████████████████████████| 462/462 [00:00<00:00, 1.96MB/s]
# tokenizer_config.json: 100%|██████████████████| 49.0/49.0 [00:00<00:00, 253kB/s]
# vocab.txt: 213kB [00:00, 14.0MB/s]
# special_tokens_map.json: 100%|██████████████████| 112/112 [00:00<00:00, 522kB/s]
# pytorch_model.bin: 100%|█████████████████████| 433M/433M [00:05<00:00, 76.7MB/s]
# Loading weights:  99%|▉| 197/199 [00:00<00:00, 3323.38it/s, Materializing param=
# Loading weights: 100%|█| 199/199 [00:00<00:00, 3256.13it/s, Materializing param=
# Loading checkpoint weights from Epoch_02_SIMCPRS_dmis-lab_biobert-v1_1_CL.pth...
#
# model.safetensors:   0%|                             | 0.00/433M [00:00<?, ?B/s]
# model.safetensors:   0%|                             | 0.00/433M [00:00<?, ?B/s]
# model.safetensors:   0%|                             | 0.00/433M [00:00<?, ?B/s]
# model.safetensors:   0%|                             | 0.00/433M [00:00<?, ?B/s]
# model.safetensors:   0%|                             | 0.00/433M [00:01<?, ?B/s]Initialized linear1_1: nn.Linear(768, 512)
# Initialized linear2_1: nn.Linear(768, 512)
# Initialized linear_main_1: nn.Linear(1918, 1406)
# Successfully loaded checkpoint weights. Missing keys: 0
#
# model.safetensors:   0%|                             | 0.00/433M [00:01<?, ?B/s]
# model.safetensors:   0%|                             | 0.00/433M [00:01<?, ?B/s]
# model.safetensors:   0%|                             | 0.00/433M [00:01<?, ?B/s]Model Mode: Multi-Class Classification
# Computing projected embeddings for all 1,406 journals...
#   0%|                                                  | 0/1406 [00:00<?, ?it/s]
#   0%|                                          | 1/1406 [00:00<14:42,  1.59it/s]
#   3%|█                                        | 38/1406 [00:01<00:31, 43.31it/s]
#   4%|█▋                                       | 58/1406 [00:01<00:31, 42.50it/s]
#   4%|█▊                                       | 63/1406 [00:01<00:31, 42.81it/s]
#   9%|███▍                                    | 121/1406 [00:02<00:18, 70.39it/s]
# model.safetensors: 100%|█████████████████████| 433M/433M [00:05<00:00, 86.4MB/s]
# 100%|███████████████████████████████████████| 1406/1406 [00:20<00:00, 68.47it/s]
# Journal projected embeddings computed successfully.
# Loading Qwen-2.5-7B-Instruct Model...
# config.json: 100%|█████████████████████████████| 663/663 [00:00<00:00, 2.43MB/s]
# tokenizer_config.json: 7.30kB [00:00, 4.30MB/s]
# vocab.json: 2.78MB [00:00, 49.1MB/s]
# merges.txt: 1.67MB [00:00, 105MB/s]
# tokenizer.json: 7.03MB [00:00, 132MB/s]
# model.safetensors.index.json: 27.8kB [00:00, 66.7MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100%|████| 15.2G/15.2G [01:11<00:00, 268MB/s]
# Fetching 4 files: 100%|███████████████████████████| 4/4 [01:15<00:00, 18.98s/it]
# Download complete: 100%|████████████████████| 15.2G/15.2G [01:16<00:00, 200MB/s]
# Loading weights: 100%|█| 339/339 [00:49<00:00,  6.82it/s, Materializing param=mo
# generation_config.json: 100%|███████████████████| 243/243 [00:00<00:00, 722kB/s]
# Qwen 2.5 7B Instruct loaded successfully.
#
# Evaluating the first 10 papers...
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#
# --- Paper 1 ---
# Title: Maximum antigen diversification in a lyme bacterial population and evolutionary ...
# Ground Truth: ISME Journal (Label: 651)
# Pointwise Top 3 Recommendations:
#   1. PLoS Pathogens (Score: -3.3358)
#   2. Virus Evolution (Score: -3.7116)
#   3. Frontiers in Cellular and Infection Microbiology (Score: -4.4014)
# Listwise Reranked Top 3 Recommendations:
#   1. Virus Evolution
#   2. PLoS Pathogens
#   3. Frontiers in Cellular and Infection Microbiology
# Listwise output:
# ### Analyses
#
# **[0] PLoS Pathogens**
# - **Fit**: The research paper focuses on the antigenic diversity of a Lyme disease bacterium and strategies to overcome pathogen diversity, which aligns well with the journal's focus on pathogen diversity, evolution, and vaccine design.
# - **Not Fit**: The paper does not primarily focus on host-pathogen interactions or the molecular basis of cellular and organismal function, which are more aligned with the journal’s broader scope.
#
# **[1] Virus Evolution**
# - **Fit**: The research paper involves the study of pathogen diversity and evolutionary strategies, which aligns perfectly with the journal’s focus on the long-term evolution of viruses and viruses as model systems for studying evolutionary processes.
# - **Not Fit**: The paper does not specifically focus on viruses, although the principles of pathogen evolution could be applicable.
#
# **[2] Frontiers in Cellular and Infection Microbiology**
# - **Fit**: The research paper deals with the antigenic diversity of a pathogen and strategies to overcome it, which fits well within the journal’s scope of pathogenic microorganisms and their interactions with hosts.
# - **Not Fit**: The paper might not fully align with the journal’s emphasis on cellular microbiology and gene regulation, which are more specific areas of interest.
#
# **[3] Frontiers in Immunology**
# - **Not Fit**: The research paper focuses on pathogen diversity and antigenic strategies rather than the host immune response, which is the primary focus of this journal.
# - **Fit**: However, the paper could be relevant if it discusses the immune response to the pathogen, which is a secondary aspect of the research.
#
# **[4] Microbiome**
# - **Not Fit**: The research paper does not primarily focus on microbial communities or the interaction between microbes and their hosts, which is the main focus of this journal.
# - **Fit**: The paper could be relevant if it discusses the role of the microbiome in pathogen diversity, which is a secondary aspect of the research.
#
# **[5] ISME Journal**
# - **Fit**: The research paper involves the study of pathogen diversity and strategies to overcome it, which aligns with the journal’s focus on microbial ecology and functional diversity of natural habitats.
# - **Not Fit**: The paper might not fully align with the journal’s emphasis on microbial interactions and host effects, which are more specific areas of interest.
#
# **[6] Briefings in Bioinformatics**
# - **Not Fit**: The research paper does not primarily focus on bioinformatics or computational methods, which is the main focus of this journal.
# - **Fit**: The paper could be relevant if it discusses the use of computational methods to understand pathogen diversity, which is a secondary aspect of the research.
#
# **[7] Computational and Structural Biotechnology Journal**
# - **Not Fit**: The research paper does not primarily focus on structural and functional studies of macromolecules or multi-component complexes, which is the main focus of this journal.
# - **Fit**: The paper could be relevant if it discusses the structural aspects of the pathogen or the use of computational methods to understand pathogen diversity, which is a secondary aspect of the research.
#
# **[8] PLoS Computational Biology**
# - **Not Fit**: The research paper does not primarily focus on computational methods or the application of computational methods to understand biological systems, which is the main focus of this journal.
# - **Fit**: The paper could be relevant if it discusses the use of computational methods to understand pathogen diversity, which is a secondary aspect of the research.
#
# **[9] Mobile DNA**
# - **Not Fit**: The research paper does not primarily focus on DNA rearrangements or mobile genetic elements, which is the main focus of this journal.
# - **Fit**: The paper could be relevant if it discusses the role of mobile genetic elements in pathogen diversity, which is a secondary aspect of the research.
#
# ### Final Ranking
#
# [1] > [0
#
# --- Paper 2 ---
# Title: Paget s Disease in Primary Total Hip Arthroplasty Is Associated With Greater In ...
# Ground Truth: Journal of Arthroplasty (Label: 763)
# Pointwise Top 3 Recommendations:
#   1. Journal of Arthroplasty (Score: 1.5329)
#   2. The Journal of the American Academy of Orthopaedic Surgeons (Score: -1.0187)
#   3. Preventing chronic disease (Score: -5.4764)
# Listwise Reranked Top 3 Recommendations:
#   1. Journal of Arthroplasty
#   2. The Journal of the American Academy of Orthopaedic Surgeons
#   3. Journal of Bone and Joint Surgery
# Listwise output:
# ### Analyses
#
# - **[0] Journal of Arthroplasty**: This journal focuses on joint replacement and its complications, which aligns well with the study on Paget's disease and its impact on total hip arthroplasty outcomes. It fits perfectly within the orthopedic and sports medicine categories.
# - **[1] The Journal of the American Academy of Orthopaedic Surgeons**: This journal covers a broad range of orthopedic topics, including clinical diagnosis and management, which makes it suitable for a study on the complications of Paget's disease during hip arthroplasty.
# - **[2] Preventing Chronic Disease**: This journal focuses on public health and chronic diseases, which might not be the best fit for a study specifically on surgical outcomes and complications. However, it could still be relevant if the study had broader implications for patient care and public health.
# - **[3] Journal of Bone and Joint Surgery**: This journal is dedicated to orthopedic surgery and research, making it highly suitable for a study on the surgical outcomes of Paget's disease during hip arthroplasty. It aligns well with the orthopedic and sports medicine categories.
# - **[4] Global Spine Journal**: While this journal focuses on spinal disorders, it might not be the best fit for a study on hip arthroplasty and Paget's disease, as the focus is more on spinal issues rather than hip surgery.
# - **[5] Journal of the American Chemical Society**: This journal is focused on all areas of chemistry and interfacing areas of science, which does not align with the orthopedic and surgical focus of the study.
# - **[6] Foot and Ankle International**: This journal focuses on foot and ankle problems, which might not be the best fit for a study on hip arthroplasty and Paget's disease unless the study had specific implications for foot and ankle care.
# - **[7] Journal of Rheumatology**: This journal focuses on rheumatology and related fields, which might not be the best fit for a study on hip arthroplasty and Paget's disease unless the study had specific implications for rheumatological conditions.
# - **[8] BMC Public Health**: This journal focuses on public health and the impact of environmental agents on human health, which might not be the best fit for a study on surgical outcomes and complications of Paget's disease during hip arthroplasty.
# - **[9] Environmental Research**: This journal focuses on the adverse effects of environmental agents on human health, which might not be the best fit for a study on surgical outcomes and complications of Paget's disease during hip arthroplasty unless the study had specific environmental implications.
#
# ### Final Ranking
#
# [0] > [1] > [3] > [2] > [6] > [7] > [8] > [9] > [4] > [5]
#
# --- Paper 3 ---
# Title: Single Molecule Correlated Chemical Probing: A Revolution in RNA Structure Analy...
# Ground Truth: Accounts of Chemical Research (Label: 15)
# Pointwise Top 3 Recommendations:
#   1. Journal of the American Chemical Society (Score: -4.7393)
#   2. ACS Chemical Biology (Score: -5.4069)
#   3. Accounts of Chemical Research (Score: -5.6009)
# Listwise Reranked Top 3 Recommendations:
#   1. Biophysical Journal
#   2. ACS Chemical Biology
#   3. Journal of the American Chemical Society
# Listwise output:
# ### Analyses
#
# - **Journal [0]:** Journal of the American Chemical Society (JACS)
#   - **Analysis:** JACS focuses on all areas of chemistry and interfacing areas of science, making it suitable for a research paper that involves chemical probing and RNA structure analysis.
#
# - **Journal [1]:** ACS Chemical Biology
#   - **Analysis:** ACS Chemical Biology emphasizes the interface between chemistry and biology, which aligns well with the chemical probing and RNA structure analysis presented in the paper.
#
# - **Journal [2]:** Accounts of Chemical Research
#   - **Analysis:** Accounts of Chemical Research focuses on providing overviews of basic research and applications in all areas of chemistry and biochemistry, which could be suitable for a detailed review of the methodology.
#
# - **Journal [3]:** Preventing Chronic Disease
#   - **Analysis:** This journal focuses on public health and chronic disease prevention, which does not align with the research on RNA structure and chemical probing.
#
# - **Journal [4]:** ACS Pharmacology and Translational Science
#   - **Analysis:** This journal covers a broad spectrum of biological sciences and translational studies, which might be relevant if the paper had a strong translational component, but it is less focused on the specific chemical probing techniques.
#
# - **Journal [5]:** Thrombosis and Haemostasis
#   - **Analysis:** This journal focuses on thrombosis, haemostasis, and related fields, which do not align with the RNA structure and chemical probing research.
#
# - **Journal [6]:** Biophysical Journal
#   - **Analysis:** Biophysical Journal is specifically aimed at biophysics, which closely aligns with the chemical probing and RNA structure analysis presented in the paper.
#
# - **Journal [7]:** CRISPR Journal
#   - **Analysis:** The CRISPR Journal focuses on gene editing and related technologies, which does not align with the chemical probing and RNA structure analysis.
#
# - **Journal [8]:** Molecular Diagnosis and Therapy
#   - **Analysis:** This journal covers molecular diagnosis and therapy, which might be relevant if the paper had a strong focus on diagnostics, but it is less aligned with the chemical probing techniques.
#
# - **Journal [9]:** ACS Synthetic Biology
#   - **Analysis:** ACS Synthetic Biology focuses on synthetic biology, genetic circuits, and metabolic engineering, which might be relevant if the paper had a strong synthetic biology component, but it is less aligned with the chemical probing techniques.
#
# ### Final Ranking List
# [6] > [1] > [0]
#
# --- Paper 4 ---
# Title: Customized passive dynamic ankle foot orthoses can improve walking economy and s...
# Ground Truth: Journal of NeuroEngineering and Rehabilitation (Label: 870)
# Pointwise Top 3 Recommendations:
#   1. Journal of NeuroEngineering and Rehabilitation (Score: -1.6271)
#   2. Annals of Physical and Rehabilitation Medicine (Score: -4.4278)
#   3. Scandinavian Journal of Medicine and Science in Sports (Score: -5.1371)
# Listwise Reranked Top 3 Recommendations:
#   1. Journal of NeuroEngineering and Rehabilitation
#   2. Annals of Physical and Rehabilitation Medicine
#   3. Scandinavian Journal of Medicine and Science in Sports
# Listwise output:
# ### Analyses
#
# - **Journal [0]:** Journal of NeuroEngineering and Rehabilitation
#   *Analysis:* The journal focuses on the intersection of neuroscience, biomedical engineering, and physical medicine and rehabilitation, which aligns well with the study's focus on passive dynamic ankle foot orthoses and their impact on walking function post-stroke.
#   *Fit:* High
#
# - **Journal [1]:** Annals of Physical and Rehabilitation Medicine
#   *Analysis:* This journal covers a broad range of rehabilitation and physical medicine topics, including musculoskeletal disorders, disabilities, and processes of rehabilitation, which closely matches the study's focus on post-stroke rehabilitation and walking function.
#   *Fit:* High
#
# - **Journal [2]:** Scandinavian Journal of Medicine and Science in Sports
#   *Analysis:* The journal covers orthopaedics, rehabilitation, sports medicine, exercise physiology, and biomechanics, which aligns well with the study’s focus on biomechanical variables and walking function.
#   *Fit:* High
#
# - **Journal [3]:** Journal of Athletic Training
#   *Analysis:* This journal focuses on athletic training, which may not directly cover the specific aspects of post-stroke rehabilitation and biomechanics.
#   *Fit:* Moderate
#
# - **Journal [4]:** Journal of Sport and Health Science
#   *Analysis:* The journal covers a wide range of topics related to sport, exercise, and health, including injury prevention, rehabilitation, and public health promotion, which aligns well with the study’s focus.
#   *Fit:* High
#
# - **Journal [5]:** Psychology of Sport and Exercise
#   *Analysis:* This journal focuses on the psychological aspects of sport and exercise, which may not be the primary focus of the study.
#   *Fit:* Low
#
# - **Journal [6]:** Sports Medicine - Open
#   *Analysis:* The journal covers sport and exercise medicine, including injury prevention and treatment, which aligns well with the study’s focus on walking function and biomechanics.
#   *Fit:* High
#
# - **Journal [7]:** Physical Therapy
#   *Analysis:* This journal focuses on physical therapy and rehabilitation, which aligns well with the study’s focus on post-stroke rehabilitation and walking function.
#   *Fit:* High
#
# - **Journal [8]:** Brain Stimulation
#   *Analysis:* The journal focuses on brain stimulation and neuromodulation, which may not be directly relevant to the study’s focus on biomechanics and walking function.
#   *Fit:* Low
#
# - **Journal [9]:** BMJ Open Sport and Exercise Medicine
#   *Analysis:* This journal covers all aspects of sport and exercise medicine, including physiology and return to play, which aligns well with the study’s focus on walking function and biomechanics.
#   *Fit:* High
#
# ### Final Ranking List
# [0] > [1] > [2] > [6] > [7] > [4] > [9]
#
# --- Paper 5 ---
# Title: Emergent dynamics of underlying regulatory network links EMT and androgen recept...
# Ground Truth: Computational and Structural Biotechnology Journal (Label: 372)
# Pointwise Top 3 Recommendations:
#   1. Neoplasia (Score: -3.7838)
#   2. Journal of Hematology and Oncology (Score: -4.8103)
#   3. Molecular Cancer (Score: -5.1526)
# Listwise Reranked Top 3 Recommendations:
#   1. Molecular Cancer
#   2. Clinical Cancer Research
#   3. Journal of Experimental and Clinical Cancer Research
# Listwise output:
# ### Analyses
#
# **[0] Journal: Neoplasia**
# - **Analysis:** Fits well. The journal focuses on cancer research and covers a broad spectrum of oncology-related topics, including molecular and genetic findings, which aligns with the research on androgen receptor and epithelial-mesenchymal transition (EMT) in prostate cancer.
#
# **[1] Journal: Journal of Hematology and Oncology**
# - **Analysis:** Fits moderately. While the journal covers both hematology and oncology, it might not focus as heavily on the molecular and genetic aspects of cancer as some other journals, which could be more relevant for this study.
#
# **[2] Journal: Molecular Cancer**
# - **Analysis:** Fits very well. The journal is dedicated to cancer research from a molecular perspective, covering topics such as cell and tumor biology, signaling, and molecular targets, which are directly relevant to the study's focus on androgen receptor and EMT.
#
# **[3] Journal: Clinical Cancer Research**
# - **Analysis:** Fits very well. The journal emphasizes clinical and translational cancer research, including clinical trials, pharmacology, and molecular alterations, making it highly suitable for a study that bridges laboratory and clinical findings.
#
# **[4] Journal: Briefings in Bioinformatics**
# - **Analysis:** Fits moderately. The journal focuses on bioinformatics and computational methods, which could be relevant for the computational aspects of the study, but it may not cover the broader biological and clinical aspects as comprehensively as other journals.
#
# **[5] Journal: PLoS Computational Biology**
# - **Analysis:** Fits moderately. The journal is focused on computational methods and their application to biological systems, which could be relevant for the computational modeling aspect of the study, but it may not cover the broader biological and clinical aspects as comprehensively as other journals.
#
# **[6] Journal: British Journal of Cancer**
# - **Analysis:** Fits moderately. The journal covers a broad range of cancer research, including translational and clinical aspects, but it may not emphasize the molecular and genetic aspects as strongly as some other journals.
#
# **[7] Journal: Journal of Experimental and Clinical Cancer Research**
# - **Analysis:** Fits very well. The journal focuses on both experimental and clinical cancer research, including translational studies and molecular alterations, making it highly suitable for a study that bridges laboratory and clinical findings.
#
# **[8] Journal: Translational Oncology**
# - **Analysis:** Fits very well. The journal is dedicated to bridging the gap between laboratory and clinical research in cancer, focusing on novel therapeutic interventions and clinical trials, which aligns well with the study's goals.
#
# **[9] Journal: Computational and Structural Biotechnology Journal**
# - **Analysis:** Fits moderately. The journal focuses on computational and structural biotechnology, which could be relevant for the computational modeling aspect of the study, but it may not cover the broader biological and clinical aspects as comprehensively as other journals.
#
# ### Final Ranking List
# [2] > [3] > [7] > [8] > [0] > [1] > [5] > [6] > [4] > [9]
#
# --- Paper 6 ---
# Title: Understanding VA s Use of and Relationships With Community Care Providers Under ...
# Ground Truth: Medical Care (Label: 995)
# Pointwise Top 3 Recommendations:
#   1. Medical Care (Score: -1.5928)
#   2. Preventing chronic disease (Score: -7.6543)
#   3. Journal of General Internal Medicine (Score: -7.9873)
# Listwise Reranked Top 3 Recommendations:
#   1. Journal of General Internal Medicine
#   2. Preventing chronic disease
#   3. JAMA network open
# Listwise output:
# ### Analyses
#
# - **Journal [0]: Medical Care**
#   - Fits: The journal focuses on healthcare administration and delivery, which aligns with the study's focus on VA's relationship with community care providers under the MISSION Act.
#
# - **Journal [1]: Preventing Chronic Disease**
#   - Fits: The journal covers public health and health policy, making it suitable for a study examining VA's partnerships with community providers.
#
# - **Journal [2]: Journal of General Internal Medicine**
#   - Fits: The journal covers internal medicine and general internal medicine, which aligns with the study's focus on VA facility directors' perspectives on community care partnerships.
#
# - **Journal [3]: JAMA Network Open**
#   - Fits: As a general medical journal, it covers a wide range of topics including health services research and clinical care, making it suitable for the study.
#
# - **Journal [4]: Diabetes Care**
#   - Does Not Fit: The journal focuses on diabetes and related conditions, which do not align with the study's focus on VA-community care partnerships.
#
# - **Journal [5]: Journal of Racial and Ethnic Health Disparities**
#   - Fits: The journal addresses health disparities, which could be relevant if the study explores disparities in care provided by community providers to veterans.
#
# - **Journal [6]: Journal of Acquired Immune Deficiency Syndromes (1999)**
#   - Does Not Fit: The journal focuses on HIV/AIDS and related infectious diseases, which do not align with the study's focus on VA-community care partnerships.
#
# - **Journal [7]: Journal of the American Medical Directors Association**
#   - Fits: The journal covers geriatrics and long-term care, which could be relevant if the study includes older veterans or long-term care aspects.
#
# - **Journal [8]: Women's Health Issues**
#   - Does Not Fit: The journal focuses on women's health issues, which do not align with the study's focus on VA-community care partnerships.
#
# - **Journal [9]: Journal of Cardiac Failure**
#   - Does Not Fit: The journal focuses on cardiology and cardiovascular medicine, which do not align with the study's focus on VA-community care partnerships.
#
# ### Final Ranking List
# [2] > [1] > [3] > [0]
#
# --- Paper 7 ---
# Title: The transition to civilian life: Impact of comorbid PTSD, chronic pain, and slee...
# Ground Truth: Psychological Trauma: Theory, Research, Practice, and Policy (Label: 1223)
# Pointwise Top 3 Recommendations:
#   1. Psychological Trauma: Theory, Research, Practice, and Policy (Score: -0.4401)
#   2. Journal of Traumatic Stress (Score: -1.8398)
#   3. Journal of Affective Disorders (Score: -5.9693)
# Listwise Reranked Top 3 Recommendations:
#   1. Psychological Trauma: Theory, Research, Practice, and Policy
#   2. Journal of Traumatic Stress
#   3. European Journal of Psychotraumatology
# Listwise output:
# ### Analyses
#
# **[0] Journal: Psychological Trauma: Theory, Research, Practice, and Policy**
# - **Analysis:** This journal focuses on a wide range of trauma-related topics, including psychological treatments, assessments, and services. The research paper aligns well with this journal's scope, particularly given its focus on the impact of comorbid PTSD, chronic pain, and sleep disturbance on social functioning and suicidal ideation.
# - **Fit:** Excellent fit.
#
# **[1] Journal: Journal of Traumatic Stress**
# - **Analysis:** This journal is specifically focused on trauma and stress, making it a strong fit for the research paper. It covers a broad range of topics related to trauma, including psychological effects, treatments, and prevention strategies.
# - **Fit:** Excellent fit.
#
# **[2] Journal: Journal of Affective Disorders**
# - **Analysis:** While this journal covers a wide range of affective disorders, including depression and mood spectrum disorders, it may not be the best fit for a study specifically focused on the impact of comorbid conditions on social functioning and suicidal ideation.
# - **Fit:** Good fit, but less specific compared to others.
#
# **[3] Journal: European Journal of Psychotraumatology**
# - **Analysis:** This journal is dedicated to understanding and treating the consequences of stress and trauma, including PTSD, depressive disorders, and other related conditions. The research paper aligns well with this journal’s focus.
# - **Fit:** Excellent fit.
#
# **[4] Journal: Journal of Psychiatric Research**
# - **Analysis:** This journal covers a broad range of topics in psychiatry, including clinical studies, basic research, and the application of clinical laboratory techniques. While it could be a suitable fit, it may not be as specialized in trauma and stress as some other options.
# - **Fit:** Good fit, but less specialized compared to others.
#
# **[5] Journal: Cultural Diversity and Ethnic Minority Psychology**
# - **Analysis:** This journal focuses on the psychological science of culture, ethnicity, and race, which may not be the primary focus of the research paper. While it could still be relevant, it may not be the best fit.
# - **Fit:** Less fit due to focus on cultural and ethnic diversity.
#
# **[6] Journal: Acta Psychiatrica Scandinavica**
# - **Analysis:** This journal focuses on clinical psychiatry and translational psychiatry, which aligns well with the research paper. However, it may not be as specialized in trauma and stress as some other options.
# - **Fit:** Good fit, but less specialized compared to others.
#
# **[7] Journal: Journal of Anxiety Disorders**
# - **Analysis:** This journal focuses on anxiety disorders, which may not be the primary focus of the research paper. While it could still be relevant, it may not be the best fit.
# - **Fit:** Less fit due to focus on anxiety disorders.
#
# **[8] Journal: Comprehensive Psychiatry**
# - **Analysis:** This journal covers a broad range of psychiatry and mental health topics, which aligns well with the research paper. However, it may not be as specialized in trauma and stress as some other options.
# - **Fit:** Good fit, but less specialized compared to others.
#
# **[9] Journal: Journal of Consulting and Clinical Psychology**
# - **Analysis:** This journal focuses on clinical and clinical health psychology, which aligns well with the research paper. However, it may not be as specialized in trauma and stress as some other options.
# - **Fit:** Good fit, but less specialized compared to others.
#
# ### Final Ranking
# [0] > [1] > [3]
#
# --- Paper 8 ---
# Title: Benchmarking microbial growth rate predictions from metagenomes....
# Ground Truth: ISME Journal (Label: 651)
# Pointwise Top 3 Recommendations:
#   1. Microbiome (Score: -1.2282)
#   2. Environmental Microbiome (Score: -2.8564)
#   3. mSystems (Score: -4.2566)
# Listwise Reranked Top 3 Recommendations:
#   1. mSystems
#   2. ISME Journal
#   3. Environmental Microbiome
# Listwise output:
# ### Analyses
#
# - **[0] Journal: Microbiome**
#   - Fits: The paper focuses on microbial growth rates and metagenomic analysis, aligning well with Microbiome's aim to address the study of microbial communities and their interactions.
#
# - **[1] Journal: Environmental Microbiome**
#   - Fits: The paper involves environmental microbiology, specifically marine prokaryotes, which aligns with the journal's focus on environmental and applied microbiology.
#
# - **[2] Journal: mSystems**
#   - Fits: The paper involves metagenomics and microbial growth rates, fitting well with mSystems' scope of high-throughput analyses and microbiome studies.
#
# - **[3] Journal: GigaScience**
#   - Fits: The paper generates extensive metagenomic data, aligning with GigaScience's focus on big data studies and open data sharing.
#
# - **[4] Journal: Briefings in Bioinformatics**
#   - Fits: The paper involves bioinformatics and metagenomics, which aligns with the journal's focus on bioinformatics tools and methodologies.
#
# - **[5] Journal: Biotechnology for Biofuels**
#   - Does Not Fit: The paper focuses on microbial growth rates rather than biotechnological processes for biofuel production.
#
# - **[6] Journal: ISME Journal**
#   - Fits: The paper involves microbial growth rates and metagenomics, aligning with ISME Journal's scope in microbial ecology and community dynamics.
#
# - **[7] Journal: BMC Biology**
#   - Fits: The paper involves biological studies, particularly in microbial growth rates and metagenomics, which aligns with BMC Biology's broad scope in biology.
#
# - **[8] Journal: Computational and Structural Biotechnology Journal**
#   - Fits: The paper involves metagenomics and computational methods, aligning with the journal's focus on computational and structural biotechnology.
#
# - **[9] Journal: Bioinformatics**
#   - Fits: The paper involves metagenomics and computational methods, aligning with Bioinformatics' focus on genome bioinformatics and computational biology.
#
# ### Final Ranking List
# [2] > [6] > [1] > [3] > [8] > [7] > [0] > [4] > [9] > [5]
#
# --- Paper 9 ---
# Title: Transcranial Direct Current Stimulation and Cognition in Neuropsychiatric Disord...
# Ground Truth: Neuroscientist (Label: 1111)
# Pointwise Top 3 Recommendations:
#   1. Frontiers in Psychiatry (Score: -2.5732)
#   2. The journal of prevention of Alzheimer's disease (Score: -3.5435)
#   3. Clinical Neuropsychiatry (Score: -4.0968)
# Listwise Reranked Top 3 Recommendations:
#   1. Clinical Neuropsychiatry
#   2. Psychopathology
#   3. Psychiatry Research
# Listwise output:
# ### Analyses
#
# - **[0] Journal: Frontiers in Psychiatry**
#   - Fits: The journal focuses on psychiatric research and mental health, aligning well with the study on transcranial direct current stimulation (tDCS) in neuropsychiatric disorders.
#
# - **[1] Journal: The Journal of Prevention of Alzheimer's Disease (JPAD)**
#   - Fits: While the journal covers a broad range of topics including Alzheimer's disease, it may not specifically focus on neuropsychiatric disorders and tDCS, making it less relevant than more specialized journals.
#
# - **[2] Journal: Clinical Neuropsychiatry**
#   - Fits: The journal aims to evaluate the effectiveness of treatments in neuropsychiatry, which aligns well with the study on tDCS and cognitive functions in various neuropsychiatric disorders.
#
# - **[3] Journal: Psychopathology**
#   - Fits: The journal covers a wide range of topics including psychopathology, neuropsychology, and neuroscience, making it suitable for the study on tDCS and cognitive functions in neuropsychiatric disorders.
#
# - **[4] Journal: American Journal of Geriatric Psychiatry**
#   - Fits: Although it focuses on geriatric psychiatry, the journal may not cover a wide enough range of neuropsychiatric disorders and tDCS applications beyond geriatric populations.
#
# - **[5] Journal: Frontiers in Aging Neuroscience**
#   - Fits: The journal focuses on aging and neural diseases, which aligns with the study on tDCS and cognitive functions in neuropsychiatric disorders, especially those related to aging.
#
# - **[6] Journal: Journal of Attention Disorders**
#   - Does Not Fit: The journal primarily focuses on attention disorders in children, adolescents, and adults, which is too narrow for the broader scope of neuropsychiatric disorders covered in the study.
#
# - **[7] Journal: Psychiatry Research**
#   - Fits: The journal covers a wide range of topics in psychiatry, including biochemical, physiological, and genetic factors, making it suitable for the study on tDCS and cognitive functions in neuropsychiatric disorders.
#
# - **[8] Journal: International Journal of Neuropsychopharmacology**
#   - Fits: The journal focuses on neuropsychopharmacology and the biological basis of psychiatric disorders, which aligns well with the study on tDCS and cognitive functions in neuropsychiatric disorders.
#
# - **[9] Journal: Clinical Psychological Science**
#   - Fits: The journal covers a wide range of clinical science topics, including the diagnosis, assessment, and treatment of mental illness, making it suitable for the study on tDCS and cognitive functions in neuropsychiatric disorders.
#
# ### Final Ranking List
#
# [2] > [3] > [7] > [8] > [0] > [5] > [1] > [9] > [4] > [6]
#
# --- Paper 10 ---
# Title: Comparison of learning curve for anterior and posterior implant placement using ...
# Ground Truth: Journal of Prosthetic Dentistry (Label: 904)
# Pointwise Top 3 Recommendations:
#   1. Journal of Prosthetic Dentistry (Score: 6.1230)
#   2. Cell Reports (Score: -2.6100)
#   3. American Journal of Orthodontics and Dentofacial Orthopedics (Score: -2.7167)
# Listwise Reranked Top 3 Recommendations:
#   1. Journal of Prosthodontics
#   2. American Journal of Orthodontics and Dentofacial Orthopedics
#   3. Clinical Implant Dentistry and Related Research
# Listwise output:
# ### Analyses
#
# - **[0] Journal of Prosthetic Dentistry**: This journal focuses on prosthetic and restorative dentistry, making it highly relevant for a study on implant placement techniques. The paper fits well within its scope.
# - **[1] Cell Reports**: This journal covers a broad range of life sciences, including cell biology and developmental biology. While the study involves implant placement, it does not align closely with the primary focus areas of this journal.
# - **[2] American Journal of Orthodontics and Dentofacial Orthopedics**: This journal is specifically aimed at orthodontic and dentofacial orthopedic topics, making it a strong fit for a study on implant placement techniques.
# - **[3] Journal of Prosthodontics**: This journal is dedicated to prosthodontics, implant, esthetic, and reconstructive dentistry, making it a perfect match for the study's focus on implant placement.
# - **[4] Developmental Cell**: This journal covers cell biology and developmental biology, which are relevant to the study but not the primary focus. The study might be of interest but is not a direct fit.
# - **[5] Cell**: Similar to Cell Reports, this journal covers a broad range of cell biology and related fields. The study might be of interest but is not a direct fit for the primary focus areas of this journal.
# - **[6] Clinical Implant Dentistry and Related Research**: This journal focuses on dental implants and related scientific subjects, making it a strong fit for the study on implant placement techniques.
# - **[7] Journal of Dentistry**: This journal covers a wide range of restorative dentistry topics, including implant dentistry, making it a suitable fit for the study.
# - **[8] American Journal of Sports Medicine**: This journal focuses on sports medicine, orthopedics, and related fields, which do not align with the primary focus of the study on implant placement techniques.
# - **[9] JAMA Network Open**: This journal covers a broad range of medical topics, including clinical care and health policy, but it is not specifically focused on dental or implant-related research.
#
# ### Final Ranking
#
# [3] > [2] > [6] > [0] > [7]
#
# ================ EVALUATION SUMMARY ================
# Total Papers Evaluated: 10
# Pointwise Stage (BioBERT + Checkpoint):
#   Accuracy@1:  0.5000
#   Accuracy@5:  0.6000
#   Accuracy@10: 0.9000
# Listwise Stage (Qwen Reranked):
#   Accuracy@1:  0.3000
#   Accuracy@5:  0.7000
#   Accuracy@10: 0.9000
# ====================================================
# Results and summary saved locally to results/medprs/
# Successfully copied results to Kaggle Output: /kaggle/working/results/
